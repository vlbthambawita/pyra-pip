# %%
# %pip install pyra-pytorch
# Out:
# Collecting pyra-pytorch
#   Downloading pyra_pytorch-0.0.2-py3-none-any.whl (5.1 kB)
# Requirement already satisfied: Pillow in ./anaconda3/envs/pytorch-new/lib/python3.8/site-packages (from pyra-pytorch) (7.1.2)
# Requirement already satisfied: numpy in ./anaconda3/envs/pytorch-new/lib/python3.8/site-packages (from pyra-pytorch) (1.18.4)
# Installing collected packages: pyra-pytorch
# Successfully installed pyra-pytorch-0.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyra_pytorch import PYRADataset
import matplotlib.pyplot as plt

# %%
data = PYRADataset("/work/vajira/DATA/hyper_kvasir/data_new/segmented_train_val/data/segmented-images/train/images",
                    "/work/vajira/DATA/hyper_kvasir/data_new/segmented_train_val/data/segmented-images/train/masks",
                    img_size=512,
                    grid_sizes=[2,4,256]

    )

# %%
plt.imshow(data[1]['img'])

# %%
plt.imshow(data[1]['grid_encode'])

# %%
plt.imshow(data[1]['mask'])

# %%
plt.imshow(data[1000]['img'])

# %%
plt.imshow(data[1000]['grid_encode'])

# %%
plt.imshow(data[1000]['mask'])

# %%
plt.imshow(data[2000]['img'])

# %%
plt.imshow(data[2000]['grid_encode'])

# %%
plt.imshow(data[2000]['mask'])
